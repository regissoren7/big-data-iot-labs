# %% [markdown]
# # 🔰 Startguide: Git + Colab + Fork
#
# Denna notebook visar:
# 1. **Forkar** repo på GitHub
# 2. **Klonar** din fork i **Google Colab**
# 3. Jobbar i labbmappen
# 4. **Pushar** tillbaka dina ändringar till **din egen fork**

# %% [markdown]
# ## Steg 1 – Forka big-data-iot-labs repo (på GitHub)
# 1. Gå till repo  https://github.com/maryam-marzban-it/big-data-iot-labs.git
# 2. Klicka **Fork → Create fork** uppe till höger
# 3. Nu har du en egen kopia under **din profil**: `https://github.com/<DITT-ANVÄNDARNAMN>/<REPO-NAMN>`

# %% [markdown]
# ## Steg 2 – Klona din fork till Colab
# **Byt ut** `<DITT-ANVÄNDARNAMN>` och `<REPO-NAMN>` nedan.

# %%
#  Klona ditt repo (din fork) till Colab
# !git clone https://github.com/<DITT-ANVÄNDARNAMN>/<REPO-NAMN>.git
# %cd <REPO-NAMN>

# Visa filerna i repo:t
# !ls -la

# %% [markdown]
# ## Steg 3 – Gå till rätt labbmapp
# Exempel för Lab 1 (ändra sökväg om du jobbar i en annan mapp).

# %%
# Gå in i labbmappen
# %cd lab1-datainsamling
# !ls -la

# %% [markdown]
# ## Steg 4- Jobba i en egen branch, Skapa och byt till ny branch, körs inför varje lab

# %%
# !git checkout -b lab1-förnamn-efternamn

# %% [markdown]
# ## Steg 4 – Förbered push (GitHub token)
# För att kunna **pusha** till din fork behöver du en **GitHub Personal Access Token (PAT)**.
#
# **Skapa token (en gång):**
# - Gå till: https://github.com/settings/tokens → **Generate new token** (Fine-grained)
# - Ge token ett namn (t.ex. `colab-access`)
# - Välj **Repo** → ge **Read & Write** på *Contents*
# - Skapa token och **kopiera** (visas bara en gång)
#
# > **Säkerhet:** I Colab använder vi `getpass` så token inte syns eller sparas i klartext.

# %%
import getpass, os

# Ändra till ditt GitHub-användarnamn
os.environ['GITHUB_USER'] = "<DITT-ANVÄNDARNAMN>"

# Skriv in din token (visas inte på skärmen)
os.environ['GITHUB_TOKEN'] = getpass.getpass("GitHub token (klistra in här): ")

# Ställ in git-identitet (kan vara skolmejl)
# !git config --global user.name $GITHUB_USER
# !git config --global user.email "mmarzban80@gmail.com"

# %% [markdown]
# ## Steg 5 – Kolla att du är i den branchen du skapat, Lägg till, committa och pusha
# Kör detta när du vill **spara** dina ändringar på GitHub.

# %%
# Lägg till alla ändringar och pusha
# !git add -A

# Gör en commit (skriv en bra beskrivning)
# !git commit -m "Jobbar på labb 1 i egen branch"
# !git push origin lab1-arbete

# %% [markdown]
# # När labben är klar gå till din GitHub-sida och:
#
#
#
# Klickar på “Compare & pull request”
#
# Väljer att jämföra lab1 i sin fork mot main i ditt huvudrepo
#
# Skriver ett kort meddelande (t.ex. “Lab 1 submission”)
#
# Skickar pull requesten.

# %% [markdown]
# Lycka till! 🚀
